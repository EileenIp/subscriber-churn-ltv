# %% [markdown]
# # Exploration — Subscriber Churn Early-Warning & LTV Segmentation
#
# Dataset: KKBox Churn Prediction Challenge, WSDM Cup 2018 (Kaggle). See `spec-subscriber-churn-ltv.md` for the project plan.
