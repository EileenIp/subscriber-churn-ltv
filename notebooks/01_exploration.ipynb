# %% [markdown]
# # Exploration — Player Churn Early-Warning & LTV Segmentation
#
# Dataset: Gamelytics: Mobile Analytics Challenge (Kaggle, `debs2x`). See `spec-player-churn-ltv.md` for the project plan.
